# %% [markdown]
# <h1>Initialize</h1>

# %% [markdown]
# <b>Import libraries and set working directory</b>

# %%
import numpy as np
import os
import pandas as pd
from arcpy import env
from arcpy import TableToTable_conversion

# %%
dirWork = os.getcwd()
dirData = os.path.join(dirWork, r'data')
dirResults = os.path.join(dirWork, r'results')
dirLookups = os.path.join(dirWork, r'lookups')

print("Working Directory: " + dirWork)
print("Data Directory: " + dirData)
print("Results Directory: " + dirResults)
print("Lookups Directory: " + dirLookups)
# Out:
# Working Directory: E:\GitHub\UTA-Changes-Ridership-Compare
# Data Directory: E:\GitHub\UTA-Changes-Ridership-Compare\data
# Results Directory: E:\GitHub\UTA-Changes-Ridership-Compare\results
# Lookups Directory: E:\GitHub\UTA-Changes-Ridership-Compare\lookups

# %%
#define variables

dbf_TDMRoute1 = os.path.join(dirData, r'TDM1\_v831_SE19_Net19_2_Route.dbf')
dbf_TDMRoute2 = os.path.join(dirData, r'TDM2\_v831_SE19_Net19_2_Route.dbf')

csv_TDMRoute1 = os.path.join(dirResults, r'TDMRoute1.csv')
csv_TDMRoute2 = os.path.join(dirResults, r'TDMRoute2.csv')

# %%
#define lookups
csv_RouteInfo = os.path.join(dirLookups, r'RouteInfo.csv')

# %% [markdown]
# <h1>TDM Data </h1>
#
# <b>Open Route DBF from TDM and Convert to CSV</b>

# %%
# Create function that converts dbfs to csvs using arcpy
def dbfToCSV(dbf, csv):
    TableToTable_conversion(dbf, os.path.dirname(csv), os.path.basename(csv))

# Allow arcpy to overwrite output files
env.overwriteOutput = True

# convert dbfs to csvs
dbfToCSV(dbf_TDMRoute1, csv_TDMRoute1)
dbfToCSV(dbf_TDMRoute2, csv_TDMRoute2)

# %% [markdown]
# <b>Read in CSV and do some initial data checks</b>

# %%
df_TDMRoute1 = pd.read_csv(csv_TDMRoute1)
df_TDMRoute2 = pd.read_csv(csv_TDMRoute2)

# %%
# Show number of rows and columns
nRowsTDM = df_TDMRoute1.shape[0]
nColumnsTDM = df_TDMRoute1.shape[1]
print("TDM Route 1: there are {} rows and {} columns".format(nRowsTDM, nColumnsTDM))

# Show number of rows and columns
nRowsTDM = df_TDMRoute2.shape[0]
nColumnsTDM = df_TDMRoute2.shape[1]
print("TDM Route 2: there are {} rows and {} columns".format(nRowsTDM, nColumnsTDM))
# Out:
# TDM Route 1: there are 109 rows and 36 columns
# TDM Route 2: there are 110 rows and 36 columns

# %% [markdown]
# <i>Initial look at data</i>

# %%
df_TDMRoute1[['NAME','DY_BOARD']]
# Out:
#                NAME      DY_BOARD
# 0              D460    154.389999
# 1              D461    349.269989
# 2              D462    114.440002
# 3             FD605    346.119995
# 4    M805_Santaquin    406.290008
# ..              ...           ...
# 104           Green  18260.259766
# 105             Red  25033.839844
# 106           Sline    879.030029
# 107       RCRT_OGPN  23999.800781
# 108      BRT_ProOrm  13327.419922
#
# [109 rows x 2 columns]

# %%
df_TDMRoute2
# Out:
#      OID_  MODE  NAMEID            NAME  OPERATOR  ONEWAY     RT_DIST  PK_PRD  \
# 0     NaN     4     1.0            D460       0.0       1   24.400000       6
# 1     NaN     4     2.0            D461       0.0       1   38.740002       6
# 2     NaN     4     3.0            D462       0.0       1   23.440001       6
# 3     NaN     4     4.0           FD605       0.0       0   15.960000       6
# 4     NaN     4     5.0  M805_Santaquin       0.0       1   61.169998       6
# ..    ...   ...     ...             ...       ...     ...         ...     ...
# 105   NaN     7   106.0             Red       0.0       0   46.500000       6
# 106   NaN     7   107.0           Sline       0.0       0    3.520000       6
# 107   NaN     8   108.0     OGPNShuttle       0.0       0   12.320000       6
# 108   NaN     8   109.0       RCRT_OGPN       0.0       0  162.199997       6
# 109   NaN     9   110.0      BRT_ProOrm       0.0       0   22.180000       6
#
#      OK_PRD  PK_HEADWAY  ...     DY_ALIGHT  PK_VEH  OK_VEH  DY_VEH  \
# 0        10          60  ...    142.000000     2.0     0.0     2.0
# 1        10          30  ...    346.540008     5.0     0.0     5.0
# 2        10          40  ...    122.160004     3.0     0.0     3.0
# 3        10          30  ...    373.339996     2.0     2.0     2.0
# 4        10          30  ...    632.440002     4.0     0.0     4.0
# ..      ...         ...  ...           ...     ...     ...     ...
# 105      10          15  ...  27916.869141     8.0     8.0     8.0
# 106      10          15  ...    672.760010     2.0     2.0     2.0
# 107      10         360  ...    346.209992     1.0     0.0     1.0
# 108      10          30  ...  24637.599609     8.0     4.0     8.0
# 109      10           6  ...  14575.450195    14.0     9.0    14.0
#
#         PK_REVMI     OK_REVMI     DY_REVMI  PK_REVHR  OK_REVHR  DY_REVHR
# 0     146.399994     0.000000   146.399994      12.0       0.0      12.0
# 1     464.880005     0.000000   464.880005      30.0       0.0      30.0
# 2     210.960007     0.000000   210.960007      18.0       0.0      18.0
# 3     191.520004   319.200012   510.720001      12.0      20.0      32.0
# 4     734.039978     0.000000   734.039978      24.0       0.0      24.0
# ..           ...          ...          ...       ...       ...       ...
# 105  1116.000000  1860.000000  2976.000000      48.0      80.0     128.0
# 106    84.480003   140.800003   225.279999      12.0      20.0      32.0
# 107    12.320000     0.000000    12.320000       6.0       0.0       6.0
# 108  1946.400024  1622.000000  3568.399902      48.0      40.0      88.0
# 109  1330.800049  1330.800049  2661.600098      84.0      90.0     174.0
#
# [110 rows x 36 columns]

# %%
df_TDMRoute2.columns
# Out:
# Index(['OID_', 'MODE', 'NAMEID', 'NAME', 'OPERATOR', 'ONEWAY', 'RT_DIST',
#        'PK_PRD', 'OK_PRD', 'PK_HEADWAY', 'OK_HEADWAY', 'PK_RT_TIME',
#        'OK_RT_TIME', 'PK_SPEED', 'OK_SPEED', 'PK_D_BOARD', 'PK_W_BOARD',
#        'PK_BOARD', 'PK_ALIGHT', 'OK_D_BOARD', 'OK_W_BOARD', 'OK_BOARD',
#        'OK_ALIGHT', 'DY_D_BOARD', 'DY_W_BOARD', 'DY_BOARD', 'DY_ALIGHT',
#        'PK_VEH', 'OK_VEH', 'DY_VEH', 'PK_REVMI', 'OK_REVMI', 'DY_REVMI',
#        'PK_REVHR', 'OK_REVHR', 'DY_REVHR'],
#       dtype='object')

# %%
df_CompareTDMRoute1M2 = pd.DataFrame.merge(df_TDMRoute1[['NAME','DY_BOARD','DY_W_BOARD','DY_D_BOARD','OK_SPEED']].rename({'NAME': 'TDM_Name', 'DY_BOARD': 'DY_BOARD_1', 'DY_W_BOARD': 'DY_W_BOARD_1', 'DY_D_BOARD': 'DY_D_BOARD_1', 'OK_SPEED': 'OK_SPEED_1'}, axis='columns'), df_TDMRoute2[['NAME','DY_BOARD','DY_W_BOARD','DY_D_BOARD','OK_SPEED']].rename({'NAME': 'TDM_Name', 'DY_BOARD': 'DY_BOARD_2', 'DY_W_BOARD': 'DY_W_BOARD_2', 'DY_D_BOARD': 'DY_D_BOARD_2', 'OK_SPEED': 'OK_SPEED_2'}, axis='columns'), on="TDM_Name", how="outer")

# %%
df_CompareTDMRoute1M2['DY_BOARD_Diff'] = df_CompareTDMRoute1M2['DY_BOARD_1'] - df_CompareTDMRoute1M2['DY_BOARD_2']
df_CompareTDMRoute1M2['DY_W_BOARD_Diff'] = df_CompareTDMRoute1M2['DY_W_BOARD_1'] - df_CompareTDMRoute1M2['DY_W_BOARD_2']
df_CompareTDMRoute1M2['DY_D_BOARD_Diff'] = df_CompareTDMRoute1M2['DY_D_BOARD_1'] - df_CompareTDMRoute1M2['DY_D_BOARD_2']
df_CompareTDMRoute1M2['OK_SPEED_Diff'] = df_CompareTDMRoute1M2['OK_SPEED_1'] - df_CompareTDMRoute1M2['OK_SPEED_2']

# %%
df_CompareTDMRoute1M2
# Out:
#            TDM_Name    DY_BOARD_1  DY_W_BOARD_1  DY_D_BOARD_1  OK_SPEED_1  \
# 0              D460    154.389999    124.510002     29.879999   17.900000
# 1              D461    349.269989    333.959992     15.310000   18.100000
# 2              D462    114.440002    114.070000      0.370000   18.799999
# 3             FD605    346.119995    328.339996     17.780001   17.100000
# 4    M805_Santaquin    406.290008    329.190002     77.099998   41.700001
# ..              ...           ...           ...           ...         ...
# 105             Red  25033.839844  22113.669922   2920.169922   23.600000
# 106           Sline    879.030029    869.380005      9.650000   11.800000
# 107       RCRT_OGPN  23999.800781  14913.120117   9086.679688   40.599998
# 108      BRT_ProOrm  13327.419922  13009.790039    317.630005   16.799999
# 109     OGPNShuttle           NaN           NaN           NaN         NaN
#
#        DY_BOARD_2  DY_W_BOARD_2  DY_D_BOARD_2  OK_SPEED_2  DY_BOARD_Diff  \
# 0      142.000000    116.699997     25.299999   17.900000      12.389999
# 1      346.540008    327.750000     18.790001   18.100000       2.729981
# 2      122.160004    121.629997      0.530000   18.799999      -7.720001
# 3      373.339996    351.299988     22.040001   17.100000     -27.220001
# 4      632.440002    432.869995    199.570007   41.900002    -226.149994
# ..            ...           ...           ...         ...            ...
# 105  27916.869141  24597.380859   3319.489990   24.400000   -2883.029297
# 106    672.760010    672.219971      0.540000   13.800000     206.270019
# 107  24637.599609  15607.959961   9029.639648   40.599998    -637.798828
# 108  14575.450195  14290.570312    284.880005   16.200001   -1248.030273
# 109    346.209992    339.290008      6.920000   41.000000            NaN
#
#      DY_W_BOARD_Diff  DY_D_BOARD_Diff  OK_SPEED_Diff
# 0           7.810005         4.580000       0.000000
# 1           6.209992        -3.480000       0.000000
# 2          -7.559998        -0.160000       0.000000
# 3         -22.959992        -4.260000       0.000000
# 4        -103.679993      -122.470009      -0.200001
# ..               ...              ...            ...
# 105     -2483.710938      -399.320068      -0.799999
# 106       197.160034         9.110000      -2.000000
# 107      -694.839844        57.040039       0.000000
# 108     -1280.780273        32.750000       0.599998
# 109              NaN              NaN            NaN
#
# [110 rows x 13 columns]

# %% [markdown]
# <b>Use Lookup to get to Route Info</b>

# %% [markdown]
# <i>Read in Route Info csv</i>

# %%
df_RouteInfo = pd.read_csv(csv_RouteInfo)

# %%
df_RouteInfo
# Out:
#         TDM_Name Route_Num                   Route_Label  Mode  Mode_Name  \
# 0             S2         2                           002     4  Local Bus
# 1             S3         3                           003     4  Local Bus
# 2             S4         4                           004     4  Local Bus
# 3             S6         6                           006     4  Local Bus
# 4             S9         9                           009     4  Local Bus
# ..           ...       ...                           ...   ...        ...
# 107  OGPNShuttle      750s  FrontRunner to Pleasant View     8        CRT
# 108        Green       704                    TRAX-Green     7        LRT
# 109          Red       703                      TRAX-Red     7        LRT
# 110        Sline       720                        S-Line     7        LRT
# 111   BRT_ProOrm       830                           UVX     9    BRT III
#
#     Service_District
# 0          Salt Lake
# 1          Salt Lake
# 2          Salt Lake
# 3          Salt Lake
# 4          Salt Lake
# ..               ...
# 107        Salt Lake
# 108        Salt Lake
# 109        Salt Lake
# 110        Salt Lake
# 111            Provo
#
# [112 rows x 6 columns]

# %% [markdown]
# <i>Join to Lookup to add Route_Label field</i>

# %%
df_CompareTDMRoute1M2_Labels = pd.DataFrame.merge(df_CompareTDMRoute1M2, df_RouteInfo, on="TDM_Name", how="inner")

# %%
df_CompareTDMRoute1M2_Labels
# Out:
#            TDM_Name    DY_BOARD_1  DY_W_BOARD_1  DY_D_BOARD_1  OK_SPEED_1  \
# 0              D460    154.389999    124.510002     29.879999   17.900000
# 1              D461    349.269989    333.959992     15.310000   18.100000
# 2              D462    114.440002    114.070000      0.370000   18.799999
# 3             FD605    346.119995    328.339996     17.780001   17.100000
# 4    M805_Santaquin    406.290008    329.190002     77.099998   41.700001
# ..              ...           ...           ...           ...         ...
# 105             Red  25033.839844  22113.669922   2920.169922   23.600000
# 106           Sline    879.030029    869.380005      9.650000   11.800000
# 107       RCRT_OGPN  23999.800781  14913.120117   9086.679688   40.599998
# 108      BRT_ProOrm  13327.419922  13009.790039    317.630005   16.799999
# 109     OGPNShuttle           NaN           NaN           NaN         NaN
#
#        DY_BOARD_2  DY_W_BOARD_2  DY_D_BOARD_2  OK_SPEED_2  DY_BOARD_Diff  \
# 0      142.000000    116.699997     25.299999   17.900000      12.389999
# 1      346.540008    327.750000     18.790001   18.100000       2.729981
# 2      122.160004    121.629997      0.530000   18.799999      -7.720001
# 3      373.339996    351.299988     22.040001   17.100000     -27.220001
# 4      632.440002    432.869995    199.570007   41.900002    -226.149994
# ..            ...           ...           ...         ...            ...
# 105  27916.869141  24597.380859   3319.489990   24.400000   -2883.029297
# 106    672.760010    672.219971      0.540000   13.800000     206.270019
# 107  24637.599609  15607.959961   9029.639648   40.599998    -637.798828
# 108  14575.450195  14290.570312    284.880005   16.200001   -1248.030273
# 109    346.209992    339.290008      6.920000   41.000000            NaN
#
#      DY_W_BOARD_Diff  DY_D_BOARD_Diff  OK_SPEED_Diff Route_Num  \
# 0           7.810005         4.580000       0.000000       460
# 1           6.209992        -3.480000       0.000000       461
# 2          -7.559998        -0.160000       0.000000       462
# 3         -22.959992        -4.260000       0.000000       605
# 4        -103.679993      -122.470009      -0.200001       805
# ..               ...              ...            ...       ...
# 105     -2483.710938      -399.320068      -0.799999       703
# 106       197.160034         9.110000      -2.000000       720
# 107      -694.839844        57.040039       0.000000       750
# 108     -1280.780273        32.750000       0.599998       830
# 109              NaN              NaN            NaN      750s
#
#                       Route_Label  Mode  Mode_Name Service_District
# 0                             460     4  Local Bus        Salt Lake
# 1                             461     4  Local Bus        Salt Lake
# 2                             462     4  Local Bus        Salt Lake
# 3                            F605     4  Local Bus            Ogden
# 4                             805     4  Local Bus            Provo
# ..                            ...   ...        ...              ...
# 105                      TRAX-Red     7        LRT        Salt Lake
# 106                        S-Line     7        LRT        Salt Lake
# 107                   FrontRunner     8        CRT        Salt Lake
# 108                           UVX     9    BRT III            Provo
# 109  FrontRunner to Pleasant View     8        CRT        Salt Lake
#
# [110 rows x 18 columns]

# %% [markdown]
# <b>Chart TDM Boardings by Route_Label as initial look before OBS comparison</b>

# %%
df_Compare = df_CompareTDMRoute1M2_Labels.set_index(["Route_Label"])

# %%
df_Compare.sort_index(inplace=True)
df_Compare
# Out:
#                TDM_Name    DY_BOARD_1  DY_W_BOARD_1  DY_D_BOARD_1  OK_SPEED_1  \
# Route_Label
# 002                  S2   5312.379883   3874.370117   1438.010010   13.700000
# 002X                S2X     80.599998     65.040001     15.560000   13.900000
# 003                  S3    953.419983    800.450012    152.970001   14.800000
# 004                  S4   2003.150024   1952.239990     50.910000   17.700001
# 006                  S6   1630.290039   1361.829956    268.459992   14.800000
# ...                 ...           ...           ...           ...         ...
# S-Line            Sline    879.030029    869.380005      9.650000   11.800000
# TRAX-Blue          Blue  16681.279297  14344.339844   2336.939941   22.400000
# TRAX-Green        Green  18260.259766  17032.849609   1227.410034   18.600000
# TRAX-Red            Red  25033.839844  22113.669922   2920.169922   23.600000
# UVX          BRT_ProOrm  13327.419922  13009.790039    317.630005   16.799999
#
#                DY_BOARD_2  DY_W_BOARD_2  DY_D_BOARD_2  OK_SPEED_2  \
# Route_Label
# 002           5220.430176   3852.149902   1368.280029   13.700000
# 002X           340.049988    231.339996    108.709999   13.800000
# 003           1449.619995   1225.219971    224.399994   14.800000
# 004           2168.530029   2117.189941     51.340000   17.400000
# 006           1510.949951   1246.650024    264.299988   14.800000
# ...                   ...           ...           ...         ...
# S-Line         672.760010    672.219971      0.540000   13.800000
# TRAX-Blue    18669.810547  15983.240234   2686.570068   24.400000
# TRAX-Green   18109.289062  16981.619141   1127.670044   19.200001
# TRAX-Red     27916.869141  24597.380859   3319.489990   24.400000
# UVX          14575.450195  14290.570312    284.880005   16.200001
#
#              DY_BOARD_Diff  DY_W_BOARD_Diff  DY_D_BOARD_Diff  OK_SPEED_Diff  \
# Route_Label
# 002              91.949707        22.220215        69.729981       0.000000
# 002X           -259.449989      -166.299995       -93.149999       0.099999
# 003            -496.200012      -424.769958       -71.429993       0.000000
# 004            -165.380005      -164.949951        -0.430000       0.300001
# 006             119.340088       115.179932         4.160004       0.000000
# ...                    ...              ...              ...            ...
# S-Line          206.270019       197.160034         9.110000      -2.000000
# TRAX-Blue     -1988.531250     -1638.900391      -349.630127      -2.000000
# TRAX-Green      150.970703        51.230469        99.739990      -0.600000
# TRAX-Red      -2883.029297     -2483.710938      -399.320068      -0.799999
# UVX           -1248.030273     -1280.780273        32.750000       0.599998
#
#             Route_Num  Mode    Mode_Name Service_District
# Route_Label
# 002                 2     4    Local Bus        Salt Lake
# 002X               2X     6  Express Bus        Salt Lake
# 003                 3     4    Local Bus        Salt Lake
# 004                 4     4    Local Bus        Salt Lake
# 006                 6     4    Local Bus        Salt Lake
# ...               ...   ...          ...              ...
# S-Line            720     7          LRT        Salt Lake
# TRAX-Blue         701     7          LRT        Salt Lake
# TRAX-Green        704     7          LRT        Salt Lake
# TRAX-Red          703     7          LRT        Salt Lake
# UVX               830     9      BRT III            Provo
#
# [110 rows x 17 columns]

# %%
df_Compare.plot.bar(y=('DY_BOARD_1'), figsize=(20,10), fontsize=14)

# %% [markdown]
# # Compare TDM1 vs TDM2

# %%
import matplotlib.ticker as mtick
from IPython.display import display, Markdown

# %%
#chart globals

sLegend1 = "Before Updates"
sLegend2 = "After Updates"
sLegendDiff = "Difference"
sLegendPercentDiff = "% Difference"

sColor1 = "#b8880f"
sColor2 = "#00516f"

sTitle = "Daily Boardings"
sTitleShare = "Daily Boardings Share"

aFigureSize = (20,10)
iTitleSize = 36
iLegendSize = 18
iAxisItemSize = 18
iAxisTitleSize = 24

# %% [markdown]
# # Compare Daily Boardings TDM1 vs TDM2

# %%
sField1 = "DY_BOARD_2"
sField2 = "DY_BOARD_1"
sFieldDiff = "DY_BOARD_Diff"

# %%
df_Compare_Mode = df_Compare.groupby(['Mode_Name']).agg({sField1: [np.sum], sField2: [np.sum], sFieldDiff: [np.sum]})

#rename columns
df_Compare_Mode.columns = (sLegend1, sLegend2, sLegendDiff)

#add total row
df_Compare_Mode_wTotal = df_Compare_Mode.append(df_Compare_Mode.sum(numeric_only=True).rename('Total'))
df_Compare_Mode_wTotal.index.name = 'Mode'

#add percent diff
df_Compare_Mode_wTotal[sLegendPercentDiff] = df_Compare_Mode_wTotal[sLegendDiff] / df_Compare_Mode_wTotal[sLegend1]

#add title 
display(Markdown('# Boardings by Mode'))

df_Compare_Mode_wTotal.style.format({sLegend1: "{:,.0f}",sLegend2: "{:,.0f}",sLegendDiff: "{:,.0f}",sLegendPercentDiff: "{:.1%}"})
# Out:
# # Boardings by Mode
# <style  type="text/css" >
# </style><table id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Before Updates</th>        <th class="col_heading level0 col1" >After Updates</th>        <th class="col_heading level0 col2" >Difference</th>        <th class="col_heading level0 col3" >% Difference</th>    </tr>    <tr>        <th class="index_name level0" >Mode</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9level0_row0" class="row_heading level0 row0" >BRT I</th>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row0_col0" class="data row0 col0" >1,757</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row0_col1" class="data row0 col1" >1,597</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row0_col2" class="data row0 col2" >-160</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row0_col3" class="data row0 col3" >-9.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9level0_row1" class="row_heading level0 row1" >BRT III</th>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row1_col0" class="data row1 col0" >14,575</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row1_col1" class="data row1 col1" >13,327</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row1_col2" class="data row1 col2" >-1,248</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row1_col3" class="data row1 col3" >-8.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9level0_row2" class="row_heading level0 row2" >CRT</th>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row2_col0" class="data row2 col0" >24,984</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row2_col1" class="data row2 col1" >24,000</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row2_col2" class="data row2 col2" >-638</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row2_col3" class="data row2 col3" >-2.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9level0_row3" class="row_heading level0 row3" >Express Bus</th>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row3_col0" class="data row3 col0" >3,569</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row3_col1" class="data row3 col1" >3,542</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row3_col2" class="data row3 col2" >-27</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row3_col3" class="data row3 col3" >-0.7%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9level0_row4" class="row_heading level0 row4" >LRT</th>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row4_col0" class="data row4 col0" >65,369</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row4_col1" class="data row4 col1" >60,854</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row4_col2" class="data row4 col2" >-4,514</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row4_col3" class="data row4 col3" >-6.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9level0_row5" class="row_heading level0 row5" >Local Bus</th>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row5_col0" class="data row5 col0" >82,610</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row5_col1" class="data row5 col1" >79,648</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row5_col2" class="data row5 col2" >-2,962</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row5_col3" class="data row5 col3" >-3.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9level0_row6" class="row_heading level0 row6" >Total</th>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row6_col0" class="data row6 col0" >192,863</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row6_col1" class="data row6 col1" >182,968</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row6_col2" class="data row6 col2" >-9,549</td>
#                         <td id="T_8ea7308c_f69f_11ea_b7f7_1c1b0d30e1c9row6_col3" class="data row6 col3" >-5.0%</td>
#             </tr>
#     </tbody></table>

# %%
#filter dataframe to plot
df_plot = df_Compare_Mode[[sLegend1,sLegend2]]

ax = df_plot.plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Mode", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title(sTitle + " by Mode - System-Wide", fontsize=iTitleSize)

ax.legend([sLegend1, sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

#ax.set_ylim([0, 30000])

# %%
df_Compare_ServiceDistrict = df_Compare.groupby(['Service_District']).agg({sField1: [np.sum], sField2: [np.sum], sFieldDiff: [np.sum]})

#rename columns
df_Compare_ServiceDistrict.columns = (sLegend1, sLegend2, sLegendDiff)

#add total row
df_Compare_ServiceDistrict_wTotal = df_Compare_ServiceDistrict.append(df_Compare_ServiceDistrict.sum().rename('Total'))

df_Compare_ServiceDistrict_wTotal[sLegendPercentDiff] = df_Compare_ServiceDistrict_wTotal[sLegendDiff] / df_Compare_ServiceDistrict_wTotal[sLegend1]

#add title 
display(Markdown('# Boardings by Service District'))

df_Compare_ServiceDistrict_wTotal.style.format({sLegend1: "{:,.0f}",sLegend2: "{:,.0f}",sLegendDiff: "{:,.0f}",sLegendPercentDiff: "{:.1%}"})
# Out:
# # Boardings by Service District
# <style  type="text/css" >
# </style><table id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Before Updates</th>        <th class="col_heading level0 col1" >After Updates</th>        <th class="col_heading level0 col2" >Difference</th>        <th class="col_heading level0 col3" >% Difference</th>    </tr>    <tr>        <th class="index_name level0" >Service_District</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9level0_row0" class="row_heading level0 row0" > Ogden</th>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row0_col0" class="data row0 col0" >15</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row0_col1" class="data row0 col1" >21</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row0_col2" class="data row0 col2" >6</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row0_col3" class="data row0 col3" >39.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9level0_row1" class="row_heading level0 row1" >Ogden</th>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row1_col0" class="data row1 col0" >14,884</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row1_col1" class="data row1 col1" >14,163</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row1_col2" class="data row1 col2" >-721</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row1_col3" class="data row1 col3" >-4.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9level0_row2" class="row_heading level0 row2" >Provo</th>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row2_col0" class="data row2 col0" >23,889</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row2_col1" class="data row2 col1" >22,153</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row2_col2" class="data row2 col2" >-1,737</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row2_col3" class="data row2 col3" >-7.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9level0_row3" class="row_heading level0 row3" >Salt Lake</th>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row3_col0" class="data row3 col0" >154,075</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row3_col1" class="data row3 col1" >146,631</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row3_col2" class="data row3 col2" >-7,097</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row3_col3" class="data row3 col3" >-4.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9level0_row4" class="row_heading level0 row4" >Total</th>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row4_col0" class="data row4 col0" >192,863</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row4_col1" class="data row4 col1" >182,968</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row4_col2" class="data row4 col2" >-9,549</td>
#                         <td id="T_8ecc1dac_f69f_11ea_bcb7_1c1b0d30e1c9row4_col3" class="data row4 col3" >-5.0%</td>
#             </tr>
#     </tbody></table>

# %%
#filter dataframe to plot
df_plot = df_Compare_ServiceDistrict[[sLegend1,sLegend2]]

ax = df_plot.plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Service District", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title(sTitle + " by Service District - System-Wide", fontsize=iTitleSize)

ax.legend([sLegend1,sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

#ax.set_ylim([0, 30000])

# %%
df_Compare_ModeServiceDistrict = df_Compare.groupby(['Service_District','Mode_Name']).agg({sField1: [np.sum], sField2: [np.sum], sFieldDiff: [np.sum]})

#rename columns
df_Compare_ModeServiceDistrict.columns = (sLegend1, sLegend2, sLegendDiff)

df_plot = df_Compare_ModeServiceDistrict[[sLegend1,sLegend2]]

ax = df_plot.plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Service District", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title(sTitle + " by Service District - System-Wide", fontsize=iTitleSize)

ax.legend([sLegend1,sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

#ax.set_ylim([0, 30000])

# %% [markdown]
# # BRT/CRT/LRT and Express Bus Daily Boardings by Service District

# %%
#filter dataframe to plot
df_plot = df_Compare.loc[(df_Compare['Mode_Name'] != "Local Bus") & (df_Compare['Mode_Name'] != "Express Bus")]

ax = df_plot[[sField1,sField2]].plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Route", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title("BRT/CRT/LRT " + sTitle, fontsize=iTitleSize)

ax.legend([sLegend1, sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set_ylim([0, 30000])
# Out:
# (0.0, 30000.0)

# %%
#filter dataframe to plot
df_plot = df_Compare.loc[(df_Compare['Mode_Name'] == "Express Bus")]

ax = df_plot[[sField1,sField2]].plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Route", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title("Express Bus " + sTitle, fontsize=iTitleSize)

ax.legend([sLegend1, sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set_ylim([0, 1000])
# Out:
# (0.0, 1000.0)

# %% [markdown]
# # Local Bus Daily Boardings by Service District

# %%
#filter variables
sServiceDistrict = "Ogden"
sModeName = "Local Bus"

#filter dataframe to plot
df_plot = df_Compare.loc[(df_Compare['Mode_Name'] == sModeName) & (df_Compare['Service_District'] == sServiceDistrict)]

ax = df_plot[[sField1,sField2]].plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Route", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title(sModeName + " " + sTitle + " - " + sServiceDistrict, fontsize=iTitleSize)

ax.legend([sLegend1, sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set_ylim([0, 3500])
# Out:
# (0.0, 3500.0)

# %%
#filter variables
sServiceDistrict = "Salt Lake"
sModeName = "Local Bus"

#filter dataframe to plot
df_plot = df_Compare.loc[(df_Compare['Mode_Name'] == sModeName) & (df_Compare['Service_District'] == sServiceDistrict)]

ax = df_plot[[sField1,sField2]].plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Route", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title(sTitle + " - " + sModeName + " - " + sServiceDistrict, fontsize=iTitleSize)

ax.legend([sLegend1, sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set_ylim([0, 6000])
# Out:
# (0.0, 6000.0)

# %%
#filter variables
sServiceDistrict = "Provo"
sModeName = "Local Bus"

#filter dataframe to plot
df_plot = df_Compare.loc[(df_Compare['Mode_Name'] == sModeName) & (df_Compare['Service_District'] == sServiceDistrict)]

ax = df_plot[[sField1,sField2]].plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Route", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title(sModeName + " " + sTitle + " - " + sServiceDistrict, fontsize=iTitleSize)

ax.legend([sLegend1, sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set_ylim([0, 3000])
# Out:
# (0.0, 3000.0)

# %% [markdown]
# # Compare Daily Walk Boardings TDM1 vs TDM2

# %%
sField1 = "DY_W_BOARD_2"
sField2 = "DY_W_BOARD_1"
sFieldDiff = "DY_W_BOARD_Diff"

# %%
df_Compare_Mode = df_Compare.groupby(['Mode_Name']).agg({sField1: [np.sum], sField2: [np.sum], sFieldDiff: [np.sum]})

#rename columns
df_Compare_Mode.columns = (sLegend1, sLegend2, sLegendDiff)

#add total row
df_Compare_Mode_wTotal = df_Compare_Mode.append(df_Compare_Mode.sum(numeric_only=True).rename('Total'))
df_Compare_Mode_wTotal.index.name = 'Mode'

#add percent diff
df_Compare_Mode_wTotal[sLegendPercentDiff] = df_Compare_Mode_wTotal[sLegendDiff] / df_Compare_Mode_wTotal[sLegend1]

#add title 
display(Markdown('# Walk Boardings by Mode'))

df_Compare_Mode_wTotal.style.format({sLegend1: "{:,.0f}",sLegend2: "{:,.0f}",sLegendDiff: "{:,.0f}",sLegendPercentDiff: "{:.1%}"})
# Out:
# # Walk Boardings by Mode
# <style  type="text/css" >
# </style><table id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Before Updates</th>        <th class="col_heading level0 col1" >After Updates</th>        <th class="col_heading level0 col2" >Difference</th>        <th class="col_heading level0 col3" >% Difference</th>    </tr>    <tr>        <th class="index_name level0" >Mode</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9level0_row0" class="row_heading level0 row0" >BRT I</th>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row0_col0" class="data row0 col0" >1,723</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row0_col1" class="data row0 col1" >1,564</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row0_col2" class="data row0 col2" >-160</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row0_col3" class="data row0 col3" >-9.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9level0_row1" class="row_heading level0 row1" >BRT III</th>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row1_col0" class="data row1 col0" >14,291</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row1_col1" class="data row1 col1" >13,010</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row1_col2" class="data row1 col2" >-1,281</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row1_col3" class="data row1 col3" >-9.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9level0_row2" class="row_heading level0 row2" >CRT</th>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row2_col0" class="data row2 col0" >15,947</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row2_col1" class="data row2 col1" >14,913</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row2_col2" class="data row2 col2" >-695</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row2_col3" class="data row2 col3" >-4.4%</td>
#             </tr>
#             <tr>
#                         <th id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9level0_row3" class="row_heading level0 row3" >Express Bus</th>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row3_col0" class="data row3 col0" >3,017</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row3_col1" class="data row3 col1" >2,820</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row3_col2" class="data row3 col2" >-197</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row3_col3" class="data row3 col3" >-6.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9level0_row4" class="row_heading level0 row4" >LRT</th>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row4_col0" class="data row4 col0" >58,234</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row4_col1" class="data row4 col1" >54,360</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row4_col2" class="data row4 col2" >-3,874</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row4_col3" class="data row4 col3" >-6.7%</td>
#             </tr>
#             <tr>
#                         <th id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9level0_row5" class="row_heading level0 row5" >Local Bus</th>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row5_col0" class="data row5 col0" >75,630</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row5_col1" class="data row5 col1" >72,464</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row5_col2" class="data row5 col2" >-3,166</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row5_col3" class="data row5 col3" >-4.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9level0_row6" class="row_heading level0 row6" >Total</th>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row6_col0" class="data row6 col0" >168,843</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row6_col1" class="data row6 col1" >159,131</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row6_col2" class="data row6 col2" >-9,372</td>
#                         <td id="T_900253ba_f69f_11ea_8e73_1c1b0d30e1c9row6_col3" class="data row6 col3" >-5.6%</td>
#             </tr>
#     </tbody></table>

# %%
df_WalkBoardings = df_Compare_Mode.copy()
df_WalkBoardings_wTotal = df_Compare_Mode_wTotal.copy()

# %%
#filter dataframe to plot
df_plot = df_WalkBoardings

ax = df_plot[[sLegend1,sLegend2]].plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Route", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title("Walk Access Boardings by Mode", fontsize=iTitleSize)

ax.legend([sLegend1,sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set_ylim([0, 80000])
# Out:
# (0.0, 80000.0)

# %% [markdown]
# # Compare Daily Drive Boardings TDM1 vs TDM2

# %%
sField1 = "DY_D_BOARD_2"
sField2 = "DY_D_BOARD_1"
sFieldDiff = "DY_D_BOARD_Diff"

# %%
df_Compare_Mode = df_Compare.groupby(['Mode_Name']).agg({sField1: [np.sum], sField2: [np.sum], sFieldDiff: [np.sum]})

#rename columns
df_Compare_Mode.columns = (sLegend1, sLegend2, sLegendDiff)

#add total row
df_Compare_Mode_wTotal = df_Compare_Mode.append(df_Compare_Mode.sum(numeric_only=True).rename('Total'))
df_Compare_Mode_wTotal.index.name = 'Mode'

#add percent diff
df_Compare_Mode_wTotal[sLegendPercentDiff] = df_Compare_Mode_wTotal[sLegendDiff] / df_Compare_Mode_wTotal[sLegend1]

#add title 
display(Markdown('# Drive Boardings by Mode'))

df_Compare_Mode_wTotal.style.format({sLegend1: "{:,.0f}",sLegend2: "{:,.0f}",sLegendDiff: "{:,.0f}",sLegendPercentDiff: "{:.1%}"})
# Out:
# # Drive Boardings by Mode
# <style  type="text/css" >
# </style><table id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Before Updates</th>        <th class="col_heading level0 col1" >After Updates</th>        <th class="col_heading level0 col2" >Difference</th>        <th class="col_heading level0 col3" >% Difference</th>    </tr>    <tr>        <th class="index_name level0" >Mode</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9level0_row0" class="row_heading level0 row0" >BRT I</th>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row0_col0" class="data row0 col0" >33</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row0_col1" class="data row0 col1" >33</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row0_col2" class="data row0 col2" >-0</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row0_col3" class="data row0 col3" >-1.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9level0_row1" class="row_heading level0 row1" >BRT III</th>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row1_col0" class="data row1 col0" >285</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row1_col1" class="data row1 col1" >318</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row1_col2" class="data row1 col2" >33</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row1_col3" class="data row1 col3" >11.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9level0_row2" class="row_heading level0 row2" >CRT</th>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row2_col0" class="data row2 col0" >9,037</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row2_col1" class="data row2 col1" >9,087</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row2_col2" class="data row2 col2" >57</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row2_col3" class="data row2 col3" >0.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9level0_row3" class="row_heading level0 row3" >Express Bus</th>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row3_col0" class="data row3 col0" >552</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row3_col1" class="data row3 col1" >722</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row3_col2" class="data row3 col2" >170</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row3_col3" class="data row3 col3" >30.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9level0_row4" class="row_heading level0 row4" >LRT</th>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row4_col0" class="data row4 col0" >7,134</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row4_col1" class="data row4 col1" >6,494</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row4_col2" class="data row4 col2" >-640</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row4_col3" class="data row4 col3" >-9.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9level0_row5" class="row_heading level0 row5" >Local Bus</th>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row5_col0" class="data row5 col0" >6,979</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row5_col1" class="data row5 col1" >7,184</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row5_col2" class="data row5 col2" >204</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row5_col3" class="data row5 col3" >2.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9level0_row6" class="row_heading level0 row6" >Total</th>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row6_col0" class="data row6 col0" >24,020</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row6_col1" class="data row6 col1" >23,837</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row6_col2" class="data row6 col2" >-176</td>
#                         <td id="T_9029159c_f69f_11ea_963d_1c1b0d30e1c9row6_col3" class="data row6 col3" >-0.7%</td>
#             </tr>
#     </tbody></table>

# %%
df_DriveBoardings = df_Compare_Mode.copy()
df_DriveBoardings_wTotal = df_Compare_Mode_wTotal.copy()

# %%
#filter dataframe to plot
df_plot = df_DriveBoardings

ax = df_plot[[sLegend1,sLegend2]].plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize, color={sColor1, sColor2}, zorder=10)

#set x,y labels
ax.set_xlabel("Route", fontsize=iAxisTitleSize)
ax.set_ylabel("Daily Boardings", fontsize=iAxisTitleSize)

#set title
ax.set_title("Drive Access Changes by Mode", fontsize=iTitleSize)

ax.legend([sLegend1,sLegend2], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set_ylim([0, 10000])
# Out:
# (0.0, 10000.0)

# %%
df_WalkDriveCompare = pd.DataFrame.merge(df_WalkBoardings_wTotal,df_DriveBoardings_wTotal,on="Mode",how="inner")

#rename columns
df_WalkDriveCompare.columns = ("Walk " + sLegend1, "Walk " + sLegend2, "Walk " + sLegendDiff, "Walk " + sLegendPercentDiff, "Drive "+ sLegend1 , "Drive "+ sLegend2, "Drive "+ sLegendDiff, "Drive "+ sLegendPercentDiff)

df_WalkDriveCompare.style.format({"Walk " + sLegend1: "{:,.0f}", "Walk " + sLegend2: "{:,.0f}", "Walk " + sLegendDiff: "{:,.0f}", "Walk " + sLegendPercentDiff: "{:.1%}", "Drive "+ sLegend1: "{:,.0f}", "Drive "+ sLegend2: "{:,.0f}", "Drive "+ sLegendDiff: "{:,.0f}", "Drive "+ sLegendPercentDiff: "{:.1%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Walk Before Updates</th>        <th class="col_heading level0 col1" >Walk After Updates</th>        <th class="col_heading level0 col2" >Walk Difference</th>        <th class="col_heading level0 col3" >Walk % Difference</th>        <th class="col_heading level0 col4" >Drive Before Updates</th>        <th class="col_heading level0 col5" >Drive After Updates</th>        <th class="col_heading level0 col6" >Drive Difference</th>        <th class="col_heading level0 col7" >Drive % Difference</th>    </tr>    <tr>        <th class="index_name level0" >Mode</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9level0_row0" class="row_heading level0 row0" >BRT I</th>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col0" class="data row0 col0" >1,723</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col1" class="data row0 col1" >1,564</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col2" class="data row0 col2" >-160</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col3" class="data row0 col3" >-9.3%</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col4" class="data row0 col4" >33</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col5" class="data row0 col5" >33</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col6" class="data row0 col6" >-0</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row0_col7" class="data row0 col7" >-1.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9level0_row1" class="row_heading level0 row1" >BRT III</th>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col0" class="data row1 col0" >14,291</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col1" class="data row1 col1" >13,010</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col2" class="data row1 col2" >-1,281</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col3" class="data row1 col3" >-9.0%</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col4" class="data row1 col4" >285</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col5" class="data row1 col5" >318</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col6" class="data row1 col6" >33</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row1_col7" class="data row1 col7" >11.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9level0_row2" class="row_heading level0 row2" >CRT</th>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col0" class="data row2 col0" >15,947</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col1" class="data row2 col1" >14,913</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col2" class="data row2 col2" >-695</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col3" class="data row2 col3" >-4.4%</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col4" class="data row2 col4" >9,037</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col5" class="data row2 col5" >9,087</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col6" class="data row2 col6" >57</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row2_col7" class="data row2 col7" >0.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9level0_row3" class="row_heading level0 row3" >Express Bus</th>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col0" class="data row3 col0" >3,017</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col1" class="data row3 col1" >2,820</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col2" class="data row3 col2" >-197</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col3" class="data row3 col3" >-6.5%</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col4" class="data row3 col4" >552</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col5" class="data row3 col5" >722</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col6" class="data row3 col6" >170</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row3_col7" class="data row3 col7" >30.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9level0_row4" class="row_heading level0 row4" >LRT</th>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col0" class="data row4 col0" >58,234</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col1" class="data row4 col1" >54,360</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col2" class="data row4 col2" >-3,874</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col3" class="data row4 col3" >-6.7%</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col4" class="data row4 col4" >7,134</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col5" class="data row4 col5" >6,494</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col6" class="data row4 col6" >-640</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row4_col7" class="data row4 col7" >-9.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9level0_row5" class="row_heading level0 row5" >Local Bus</th>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col0" class="data row5 col0" >75,630</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col1" class="data row5 col1" >72,464</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col2" class="data row5 col2" >-3,166</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col3" class="data row5 col3" >-4.2%</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col4" class="data row5 col4" >6,979</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col5" class="data row5 col5" >7,184</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col6" class="data row5 col6" >204</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row5_col7" class="data row5 col7" >2.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9level0_row6" class="row_heading level0 row6" >Total</th>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row6_col0" class="data row6 col0" >168,843</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b0d30e1c9row6_col1" class="data row6 col1" >159,131</td>
#                         <td id="T_9046fddc_f69f_11ea_b5f3_1c1b

# %%
#filter dataframe to plot
df_plot = df_WalkDriveCompare[["Walk " + sLegendPercentDiff,"Drive " + sLegendPercentDiff]]

ax = df_plot.plot.bar(figsize=aFigureSize, fontsize=iAxisItemSize,  zorder=10)

#set x,y labels
ax.set_xlabel("Mode", fontsize=iAxisTitleSize)
ax.set_ylabel("Percent Difference", fontsize=iAxisTitleSize)

#set title
ax.set_title("Walk and Drive Access Changes by Mode", fontsize=iTitleSize)

ax.legend(["Walk " + sLegendPercentDiff, "Drive " + sLegendPercentDiff], prop=dict(size=iLegendSize));

ax.grid('on', which='major', axis='y', linestyle='-', linewidth=0.5, zorder=1)

ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:.1%}'))

ax.set_ylim([-.4, .4])
# Out:
# (-0.4, 0.4)

# %% [markdown]
# # Compare Speed for BRT/CRT/LRT

# %%
sField1 = "OK_SPEED_2"
sField2 = "OK_SPEED_1"
sFieldDiff = "OK_SPEED_Diff"

# %%
df_Compare
# Out:
#                TDM_Name    DY_BOARD_1  DY_W_BOARD_1  DY_D_BOARD_1  OK_SPEED_1  \
# Route_Label
# 002                  S2   5312.379883   3874.370117   1438.010010   13.700000
# 002X                S2X     80.599998     65.040001     15.560000   13.900000
# 003                  S3    953.419983    800.450012    152.970001   14.800000
# 004                  S4   2003.150024   1952.239990     50.910000   17.700001
# 006                  S6   1630.290039   1361.829956    268.459992   14.800000
# ...                 ...           ...           ...           ...         ...
# S-Line            Sline    879.030029    869.380005      9.650000   11.800000
# TRAX-Blue          Blue  16681.279297  14344.339844   2336.939941   22.400000
# TRAX-Green        Green  18260.259766  17032.849609   1227.410034   18.600000
# TRAX-Red            Red  25033.839844  22113.669922   2920.169922   23.600000
# UVX          BRT_ProOrm  13327.419922  13009.790039    317.630005   16.799999
#
#                DY_BOARD_2  DY_W_BOARD_2  DY_D_BOARD_2  OK_SPEED_2  \
# Route_Label
# 002           5220.430176   3852.149902   1368.280029   13.700000
# 002X           340.049988    231.339996    108.709999   13.800000
# 003           1449.619995   1225.219971    224.399994   14.800000
# 004           2168.530029   2117.189941     51.340000   17.400000
# 006           1510.949951   1246.650024    264.299988   14.800000
# ...                   ...           ...           ...         ...
# S-Line         672.760010    672.219971      0.540000   13.800000
# TRAX-Blue    18669.810547  15983.240234   2686.570068   24.400000
# TRAX-Green   18109.289062  16981.619141   1127.670044   19.200001
# TRAX-Red     27916.869141  24597.380859   3319.489990   24.400000
# UVX          14575.450195  14290.570312    284.880005   16.200001
#
#              DY_BOARD_Diff  DY_W_BOARD_Diff  DY_D_BOARD_Diff  OK_SPEED_Diff  \
# Route_Label
# 002              91.949707        22.220215        69.729981       0.000000
# 002X           -259.449989      -166.299995       -93.149999       0.099999
# 003            -496.200012      -424.769958       -71.429993       0.000000
# 004            -165.380005      -164.949951        -0.430000       0.300001
# 006             119.340088       115.179932         4.160004       0.000000
# ...                    ...              ...              ...            ...
# S-Line          206.270019       197.160034         9.110000      -2.000000
# TRAX-Blue     -1988.531250     -1638.900391      -349.630127      -2.000000
# TRAX-Green      150.970703        51.230469        99.739990      -0.600000
# TRAX-Red      -2883.029297     -2483.710938      -399.320068      -0.799999
# UVX           -1248.030273     -1280.780273        32.750000       0.599998
#
#             Route_Num  Mode    Mode_Name Service_District
# Route_Label
# 002                 2     4    Local Bus        Salt Lake
# 002X               2X     6  Express Bus        Salt Lake
# 003                 3     4    Local Bus        Salt Lake
# 004                 4     4    Local Bus        Salt Lake
# 006                 6     4    Local Bus        Salt Lake
# ...               ...   ...          ...              ...
# S-Line            720     7          LRT        Salt Lake
# TRAX-Blue         701     7          LRT        Salt Lake
# TRAX-Green        704     7          LRT        Salt Lake
# TRAX-Red          703     7          LRT        Salt Lake
# UVX               830     9      BRT III            Provo
#
# [110 rows x 17 columns]

# %%
df_Compare_BRTCRTLRT = df_Compare.loc[(df_Compare['Mode_Name'] != "Local Bus") & (df_Compare['Mode_Name'] != "Express Bus")]

df_Compare_Speed = df_Compare_BRTCRTLRT[[sField1,sField2,sFieldDiff]]

#rename columns
df_Compare_Speed.columns = (sLegend1, sLegend2, sLegendDiff)

#add percent diff
df_Compare_Speed[sLegendPercentDiff] = df_Compare_Speed[sLegendDiff] / df_Compare_Speed[sLegend1]

#add title 
display(Markdown('# Off-Peak Speed Differences for BRT/LRT/CRT Routes'))

df_Compare_Speed.style.format({sLegend1: "{:,.1f}",sLegend2: "{:,.1f}",sLegendDiff: "{:,.1f}",sLegendPercentDiff: "{:.1%}"})
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# # Off-Peak Speed Differences for BRT/LRT/CRT Routes
# <style  type="text/css" >
# </style><table id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Before Updates</th>        <th class="col_heading level0 col1" >After Updates</th>        <th class="col_heading level0 col2" >Difference</th>        <th class="col_heading level0 col3" >% Difference</th>    </tr>    <tr>        <th class="index_name level0" >Route_Label</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row0" class="row_heading level0 row0" >035M</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row0_col0" class="data row0 col0" >21.5</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row0_col1" class="data row0 col1" >21.5</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row0_col2" class="data row0 col2" >0.0</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row0_col3" class="data row0 col3" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row1" class="row_heading level0 row1" >FrontRunner</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row1_col0" class="data row1 col0" >40.6</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row1_col1" class="data row1 col1" >40.6</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row1_col2" class="data row1 col2" >0.0</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row1_col3" class="data row1 col3" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row2" class="row_heading level0 row2" >FrontRunner to Pleasant View</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row2_col0" class="data row2 col0" >41.0</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row2_col3" class="data row2 col3" >nan%</td>
#             </tr>
#             <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row3" class="row_heading level0 row3" >S-Line</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row3_col0" class="data row3 col0" >13.8</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row3_col1" class="data row3 col1" >11.8</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row3_col2" class="data row3 col2" >-2.0</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row3_col3" class="data row3 col3" >-14.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row4" class="row_heading level0 row4" >TRAX-Blue</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row4_col0" class="data row4 col0" >24.4</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row4_col1" class="data row4 col1" >22.4</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row4_col2" class="data row4 col2" >-2.0</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row4_col3" class="data row4 col3" >-8.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row5" class="row_heading level0 row5" >TRAX-Green</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row5_col0" class="data row5 col0" >19.2</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row5_col1" class="data row5 col1" >18.6</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row5_col2" class="data row5 col2" >-0.6</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row5_col3" class="data row5 col3" >-3.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row6" class="row_heading level0 row6" >TRAX-Red</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row6_col0" class="data row6 col0" >24.4</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row6_col1" class="data row6 col1" >23.6</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row6_col2" class="data row6 col2" >-0.8</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row6_col3" class="data row6 col3" >-3.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9level0_row7" class="row_heading level0 row7" >UVX</th>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row7_col0" class="data row7 col0" >16.2</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row7_col1" class="data row7 col1" >16.8</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row7_col2" class="data row7 col2" >0.6</td>
#                         <td id="T_906f465c_f69f_11ea_8e4b_1c1b0d30e1c9row7_col3" class="data row7 col3" >3.7%</td>
#             </tr>
#     </tbody></table>
